# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

path = "../dataset_images/20151101_145049.jpg"
image  = cv2.imread(path)
plt.imshow(image)

# %%
border = cv2.copyMakeBorder(image , 100,100,0,0,cv2.BORDER_REFLECT_101  )
plt.imshow(border)

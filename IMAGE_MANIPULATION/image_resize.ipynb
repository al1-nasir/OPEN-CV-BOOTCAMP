# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../dataset_images/20151101_145049.jpg")

# %%
plt.imshow(image)

# %%
half = cv2.resize(image , (0,0) , fx = 0.1 , fy = 0.1)
plt.imshow(half)

# %%
bigger  = cv2.resize(image , (1050,2340))

# %%
plt.imshow(bigger)

# %%
stretch_near = cv2.resize(image , (780,540) , interpolation= cv2.INTER_LINEAR)
plt.imshow(stretch_near)
